# %%
import pandas as pd
import numpy as np

# %% [raw]
# # ----------------------------
# # Landing Geometry (Cups / Balance Landings)
# # ----------------------------
#
# cups = [
#     "Big Cup",
#     "Small Cup",
#     "Base Cup",
#     "Lighthouse",
#     "Lunar",
#     "Trade Lunar",
#     "Stilt",
#     "Spike"
# ]
#
# # ----------------------------
# # Ken-Oriented Landings
# # ----------------------------
#
# ken_landings = [
#     "Spike",
#     "Downspike",
#     "Earth Turn",
#     "Jumping Stick",
#     "Gunslinger Spike"
# ]
#
# # ----------------------------
# # Tama-Oriented Landings
# # ----------------------------
#
# tama_landings = [
#     "Airplane",
#     "Stuntplane",
#     "Whirlwind",
#     "Around Japan",
#     "Around Europe",
#     "Around USA"
# ]
#
# # ----------------------------
# # Stalls / Balance States
# # ----------------------------
#
# stalls = [
#     "Bird",
#     "Nightingale",
#     "Handlestall",
#     "Wing",
#     "Lighthouse Stall",
#     "Lunar Stall",
#     "Stilt Stall",
#     "Tap",
#     "Turntable",
#     "Ken Stall",
#     "Sara Stall"
# ]
#
# # ----------------------------
# # Juggle / Aerial Components
# # ----------------------------
#
# juggles = [
#     "Single Juggle",
#     "Double Juggle",
#     "Triple Juggle",
#     "Spacewalk",
#     "Juggle Lighthouse",
#     "Juggle Lunar",
#     "Juggle Bird"
# ]
#
# # ----------------------------
# # String / Technical Elements
# # ----------------------------
#
# string_tricks = [
#     "Pull Up",
#     "Around the World",
#     "Orbit",
#     "UFO",
#     "Moon Circle",
#     "Moshikame",
#     "Figure Eight"
# ]
#
# # ----------------------------
# # Grip States
# # ----------------------------
#
# grips = [
#     "Standard Grip",
#     "Ken Grip",
#     "Tama Grip",
#     "Sara Grip",
#     "Base Grip",
#     "Switch Grip"
# ]
#
# # ----------------------------
# # Flow / Transition Elements
# # ----------------------------
#
# transitions = [
#     "Cup to Cup",
#     "Cup to Spike",
#     "Spike to Cup",
#     "Balance to Spike",
#     "Spike to Balance",
#     "Swap Cup",
#     "Trade"
# ]
#
# # ----------------------------
# # Turns (Isolated Axis)
# # ----------------------------
#
# turns = [
#     "Zero Turn",
#     "One Turn",
#     "Two Turn",
#     "Inward Turn",
#     "Outward Turn"
# ]

# %%
transitions = [
    'Tap', 
    'Juggle', 
    'Kenflip', 
    'Ghost', 
    'Fasthand'
]

ken_grip = [
    'Spike', 
    'Downspike', 
    'Big Cup', 
    'Small Cup', 
    'Base Cup'
]

tama_grip = [
    'Airplane', 
    'Stuntplane', 
    'Stilt', 
    'Lunar', 
    'Lighthouse', 
    'J-stick'
]

after_spike = [
    'Earthturn', 
    'Juggle', 
    'Gunslinger'
]

stalls = [
    'Bird', 
    'Nightingale', 
    'Handle Stall', 
    'Wing'
]

grip = [
    'regular', 
    'penguin', 
    'sara'
]

start = [
    'swing', 
    'pull-up'
]

around_tricks = [
    'Around Japan', 
    'Around USA', 
    'Around Europe', 
    'Around Tunbridge'
]

# %%
probabilities = {}
